# %% [markdown]
# # ALS sample analysis

# %%
from env import neptune_api_token

config = {
    'entity': 'ejmockler',
    'project': 'ALS-NUPs-NoHyperParamOptimization',
    'neptuneApiToken': neptune_api_token,
}

# %%
import neptune
import pandas as pd
project = neptune.init_project(project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
runs_table_df = project.fetch_runs_table().to_pandas()
# Out:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/

# %%
runs_table_df
# Out:
#                    sys/creation_time sys/description  sys/failed sys/hostname
# 0   2023-06-04 12:19:03.283000+00:00                       False         noot  \
# 1   2023-06-04 12:19:00.333000+00:00                       False         noot
# 2   2023-06-04 12:18:53.513000+00:00                       False         noot
# 3   2023-06-04 12:18:50.530000+00:00                       False         noot
# 4   2023-06-04 12:18:44.819000+00:00                       False         noot
# ..                               ...             ...         ...          ...
# 415 2023-06-04 09:33:46.765000+00:00                       False         noot
# 416 2023-06-04 09:33:42.870000+00:00                       False         noot
# 417 2023-06-04 09:33:38.064000+00:00                       False         noot
# 418 2023-06-04 09:33:34.171000+00:00                       False         noot
# 419 2023-06-04 09:33:29.041000+00:00                       False         noot
#
#              sys/id            sys/modification_time  sys/monitoring_time
# 0    NUPNOPARAM-853 2023-06-04 22:00:19.380000+00:00                  512  \
# 1    NUPNOPARAM-852 2023-06-04 20:36:14.786000+00:00                  137
# 2    NUPNOPARAM-851 2023-06-04 20:36:15.751000+00:00                  140
# 3    NUPNOPARAM-850 2023-06-04 20:36:16.718000+00:00                  142
# 4    NUPNOPARAM-849 2023-06-04 20:36:17.709000+00:00                  146
# ..              ...                              ...                  ...
# 415  NUPNOPARAM-438 2023-06-04 20:36:36.789000+00:00                  126
# 416  NUPNOPARAM-437 2023-06-04 20:36:37.756000+00:00                  132
# 417  NUPNOPARAM-436 2023-06-04 20:36:39.027000+00:00                  141
# 418  NUPNOPARAM-435 2023-06-04 20:36:40.255000+00:00                  162
# 419  NUPNOPARAM-434 2023-06-04 20:36:41.405000+00:00                  142
#
#      sys/name  sys/owner                    sys/ping_time  ...
# 0    Untitled  ejmockler 2023-06-04 22:00:19.380000+00:00  ...  \
# 1    Untitled  ejmockler 2023-06-04 20:36:14.786000+00:00  ...
# 2    Untitled  ejmockler 2023-06-04 20:36:15.751000+00:00  ...
# 3    Untitled  ejmockler 2023-06-04 20:36:16.718000+00:00  ...
# 4    Untitled  ejmockler 2023-06-04 20:36:17.709000+00:00  ...
# ..        ...        ...                              ...  ...
# 415  Untitled  ejmockler 2023-06-04 20:36:36.789000+00:00  ...
# 416  Untitled  ejmockler 2023-06-04 20:36:37.756000+00:00  ...
# 417  Untitled  ejmockler 2023-06-04 20:36:39.027000+00:00  ...
# 418  Untitled  ejmockler 2023-06-04 20:36:40.255000+00:00  ...
# 419  Untitled  ejmockler 2023-06-04 20:36:41.405000+00:00  ...
#
#      monitoring/fbb27e7c/tid  monitoring/fcd57521/hostname
# 0                        NaN                           NaN  \
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
# ..                       ...                           ...
# 415                      NaN                           NaN
# 416                      NaN                           NaN
# 417                      NaN                           NaN
# 418                      NaN                           NaN
# 419                      NaN                           NaN
#
#     monitoring/fcd57521/pid monitoring/fcd57521/tid
# 0                       NaN                     NaN  \
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ..                      ...                     ...
# 415                     NaN                     NaN
# 416                     NaN                     NaN
# 417                     NaN                     NaN
# 418                     NaN                     NaN
# 419                     NaN                     NaN
#
#      monitoring/fce42522/hostname  monitoring/fce42522/pid
# 0                             NaN                      NaN  \
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             NaN                      NaN
# ..                            ...                      ...
# 415                           NaN                      NaN
# 416                           NaN                      NaN
# 417                           NaN                      NaN
# 418                           NaN                      NaN
# 419                           NaN                      NaN
#
#     monitoring/fce42522/tid monitoring/fe28c34a/hostname
# 0                       NaN                          NaN  \
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# ..                      ...                          ...
# 415                     NaN                          NaN
# 416                     NaN                          NaN
# 417                     NaN                          NaN
# 418                     NaN                          NaN
# 419                     NaN                          NaN
#
#     monitoring/fe28c34a/pid monitoring/fe28c34a/tid
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ..                      ...                     ...
# 415                     NaN                     NaN
# 416                     NaN                     NaN
# 417                     NaN                     NaN
# 418                     NaN                     NaN
# 419                     NaN                     NaN
#
# [420 rows x 820 columns]

# %%
import multiprocess as multiprocessing
import neptune
import os
# %env NEPTUNE_ALLOW_SELF_SIGNED_CERTIFICATE='TRUE'

def download_file(run_id, field='sampleResults', extension='csv'):
    path = f'./{field}/{run_id}.{extension}'
    if not os.path.exists(field):
        os.mkdir(field)
    if os.path.isfile(path): 
        return
    run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
    if field == 'globalFeatureImportance' or field == 'testLabels':
        for i in range(11):
            try:
                path = f'./{field}/{run_id}_{i}.{extension}'
                run[f"{field}/{i}"].download(destination=path)
            except:
                pass
    else: run[field].download(destination=path)
    run.stop()
    

# Get the number of available CPUs
cpu_count = multiprocessing.cpu_count()

# Create a list of tuples containing the run ID and the corresponding function call
sample_probability_tasks = [(download_file, run['sys/id']) for _, run in runs_table_df.iterrows()]
sample_label_tasks = [(download_file, run['sys/id'], 'testLabels', 'csv') for _, run in runs_table_df.iterrows()]
# shap_tasks = [(download_file, run['sys/id'], 'shapExplanationsPerFold', 'pkl') for _, run in runs_table_df.iterrows()]
embedding_tasks = [(download_file, run['sys/id'], 'embedding', 'csv') for _, run in runs_table_df.iterrows()]
# global_importance_tasks = [(download_file, run['sys/id'], 'globalFeatureImportance', 'csv') for _, run in runs_table_df.iterrows()]

with multiprocessing.Pool(cpu_count) as pool:
    # Use the multiprocessing Pool to map the tasks to different processes
    pool.starmap(lambda func, *args: func(*args), sample_probability_tasks)
    pool.starmap(lambda func, *args: func(*args), sample_label_tasks)
    # pool.starmap(lambda func, *args: func(*args), shap_tasks)
    pool.starmap(lambda func, *args: func(*args), embedding_tasks)
    # pool.starmap(lambda func, *args: func(*args), global_importance_tasks)
# Out:
# env: NEPTUNE_ALLOW_SELF_SIGNED_CERTIFICATE='TRUE'
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# /tmp/ipykernel_183804/4011975909.py:12: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-604
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-618
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-534
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-576
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-569
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-541
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-555
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-590
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-520
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-611
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-625
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-548
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-562
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-597
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-527
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-583
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# All 0 operations synced, thanks for waiting!
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-618/metadata
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-534/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-541/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-576/metadata
# Done!
# Done!
# All 0 operations synced, thanks for waiting!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-604/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-569/metadata
# Done!
# Shutting down background jobs, please wait a moment...
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-555/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-611/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-590/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-562/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-527/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-625/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-548/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-583/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-520/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-597/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-533
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-617
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-540
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-603
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-575
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-568
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-554
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-610
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-561
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-589
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-526
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-624
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-547
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-582
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-519
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-596
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-568/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-533/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-575/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-540/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-617/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-554/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Done!
# Explore the metadata in the Neptune app:
# All 0 operations synced, thanks for waiting!
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-603/metadata
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-589/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-526/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Shutting down background jobs, please wait a moment...
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-547/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-610/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-582/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-624/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-561/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-519/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-596/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-567
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-532
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-539
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-574
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-616
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-553
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-588
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-602
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-525
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-546
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-609
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-623
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-581
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-560
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-518
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-595
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-567/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-532/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-539/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-574/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-616/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-553/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-546/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-602/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-588/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-623/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-581/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-525/metadata
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-517
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-518/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-510
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-609/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-503
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-496
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-595/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-489
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-482
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-475
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-468
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-461
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-454
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-447
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-440
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-560/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-503/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-496/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-510/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-517/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-489/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-475/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-461/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-482/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-468/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-447/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-454/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-440/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-502
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-495
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-509
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-516
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-488
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-474
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-460
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-481
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-467
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-446
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-453
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-439
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-502/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-495/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# Done!
# All 0 operations synced, thanks for waiting!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-488/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-509/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-516/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-474/metadata
# Done!
# Done!
# All 0 operations synced, thanks for waiting!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-467/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-460/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-481/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-446/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-453/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-501
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-439/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-494
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-487
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-508
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-515
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-473
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-459
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-466
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-480
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-445
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-452
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-438
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-501/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-494/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-487/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-508/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-473/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-515/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-459/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-480/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-466/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-445/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-452/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-438/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-500
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-493
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-486
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-507
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-472
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-514
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-479
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-458
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-465
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-444
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-451
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-437
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-500/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-493/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-486/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-472/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-514/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-458/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# Done!
# All 0 operations synced, thanks for waiting!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-465/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-479/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-507/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-444/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-451/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-437/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-499
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-492
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-485
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-471
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-457
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-513
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-464
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-478
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-506
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-443
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-450
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-436
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-499/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-492/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-485/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-471/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-513/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-478/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-464/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-457/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-506/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-450/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-436/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-498
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-491
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-443/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-484
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-470
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-512
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-477
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-463
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-456
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-505
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-449
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-435
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-442
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-491/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-498/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Shutting down background jobs, please wait a moment...
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-470/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-484/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-512/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-477/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-463/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-456/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-505/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-449/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-435/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-490
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-497
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-469
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-442/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-483
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-511
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-476
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-462
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-455
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-504
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-448
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-434
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-441
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-469/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# ...
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-480/metadata
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-506
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-487/metadata
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-445
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-438
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-512
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-459/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-499
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-466/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-452/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-472
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-492
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-479
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-506/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-486
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-458
# Done!
# Done!
# All 0 operations synced, thanks for waiting!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-445/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-438/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-512/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-465
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-451
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-499/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-472/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-505
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-479/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-486/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-437
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-444
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-492/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-511
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-498
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-458/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-465/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-471
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-505/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-478
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-485
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-451/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-491
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-457
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-444/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-464
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-504
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-471/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-511/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-498/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-450
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-478/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-437/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-485/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-443
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-491/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-457/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-464/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-470
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-497
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-504/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-477
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-436
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-450/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-484
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-490
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-456
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-443/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-463
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-497/metadata
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-449
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-477/metadata
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-436/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-484/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-456/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-442
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-470/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-463/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-490/metadata
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-476
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-449/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-435
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-483
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-455
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-469
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-442/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-462
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-448
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-476/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-435/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-455/metadata
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-441
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-469/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-462/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-483/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-434
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-448/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-441/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-434/metadata

# %%
globalImportance_file_list
# Out:
# []

# %%
from functools import partial

def process_csv(file_path, keepRunId=False):
    df = pd.read_csv(file_path)
    filename_stem = os.path.splitext(os.path.basename(file_path))[0]
    if keepRunId: df['run'] = filename_stem
    return df

def process_attribute(dataframe, run_id, field):
    run = neptune.init_run(with_id=run_id, project=config['entity'] + '/' + config['project'], api_token=config['neptuneApiToken'])
    dataframe[field] = [*run[field].fetch()] * len(dataframe)
    run.stop()
    return dataframe

result_path = 'sampleResults/'
embedding_path = 'embedding/'
result_file_list = []

def build_file_list(path):
    file_list = []
    for filename in os.listdir(path):
        if filename.endswith(".csv"):
            file_path = os.path.join(path, filename)
            file_list.append(file_path)
    return file_list

#globalImportance_path = 'globalFeatureImportance/'
#globalImportance_file_list = build_file_list(globalImportance_path)
    
result_file_list = build_file_list(result_path)
embedding_path_list = build_file_list(embedding_path)

with multiprocessing.Pool() as pool:
    processSampleResultCSV = partial(process_csv, keepRunId=True)
    dataframes = pool.map(processSampleResultCSV, result_file_list)
    embeddingDataframes = pool.map(process_csv, embedding_path_list)
    # globalFeatureImportanceDataframes = pool.map(process_csv, globalImportance_file_list)
metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-464/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-450/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-457/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-436/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-443/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-512
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-505
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-498
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-491
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-477
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-484
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-470
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-463
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-449
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-456
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-435
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-442
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-512/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-505/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-498/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-491/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-477/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-484/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-470/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-463/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-449/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-456/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-435/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-442/metadata
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-511
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-504
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-497
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-490
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-476
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-483
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-469
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-462
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-448
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-455
# Shutting down background jobs, please wait a moment...
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-434
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-441
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Shutting down background jobs, please wait a moment...
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-511/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-504/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-497/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-490/metadata
# Shutting down background jobs, please wait a moment...
# Shutting down background jobs, please wait a moment...
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-476/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-483/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-469/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-462/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-448/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-455/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-434/metadata
# Done!
# All 0 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://new-ui.neptune.ai/ejmockler/ALS-NUPs-NoHyperParamOptimization/e/NUPNOPARAM-441/metadata

# %%
variants = globalFeatureImportanceDataframes[0]['Unnamed: 0'].to_list()

# %%
globalFeatureImportanceDataframes = [runDataframe.set_index('Unnamed: 0', drop=True) for runDataframe in globalFeatureImportanceDataframes if 'Unnamed: 0' in runDataframe.columns]
globalFeatureImportanceDataframes = [runDataframe.set_index(runDataframe.index.rename('variant')) for runDataframe in globalFeatureImportanceDataframes]
for i in range(len(globalFeatureImportanceDataframes)):
    globalFeatureImportanceDataframes[i].index = variants

# %%
globalImportanceDataframes = pd.concat(globalFeatureImportanceDataframes)
globalImportanceDataframes = globalImportanceDataframes

# %%
caseGlobalFeatureImportances = globalImportanceDataframes[['feature_importances_case']].reset_index()

# %%
averageCaseGlobalFeatureImportances = caseGlobalFeatureImportances.groupby(['index']).mean()
averageCaseGlobalFeatureImportances['feature_importances_case'] = averageCaseGlobalFeatureImportances['feature_importances_case'].abs()
averageCaseGlobalFeatureImportances = averageCaseGlobalFeatureImportances.sort_values('feature_importances_case', ascending=False)

# %%
averageCaseGlobalFeatureImportances.sort_values('feature_importances_case', ascending=False).to_csv('averageModelImportanceCoefficients.csv')

# %%
sampleResults
# Out:
#                                          id  probability             run
# 0     aals-ALS__CGND-HDA-04086__NEUDH813DE6     0.498972  NUPNOPARAM-528  \
# 1     aals-ALS__CGND-HDA-04082__NEUTB997GDW     0.502975  NUPNOPARAM-528
# 2     aals-ALS__CGND-HDA-04081__NEUAD952KAZ     0.498127  NUPNOPARAM-528
# 3     aals-ALS__CGND-HDA-04079__NEUMT573TE9     0.499165  NUPNOPARAM-528
# 4     aals-ALS__CGND-HDA-04069__NEUEA668FYK     0.500982  NUPNOPARAM-528
# ...                                     ...          ...             ...
# 1363                                NA20796     1.000000         NUP-357
# 1364                                NA20804     1.000000         NUP-357
# 1365                                NA20809     1.000000         NUP-357
# 1366                                NA20811     1.000000         NUP-357
# 1367                                NA20828     0.000000         NUP-357
#
#                    model
# 0          XGBClassifier
# 1          XGBClassifier
# 2          XGBClassifier
# 3          XGBClassifier
# 4          XGBClassifier
# ...                  ...
# 1363  LogisticRegression
# 1364  LogisticRegression
# 1365  LogisticRegression
# 1366  LogisticRegression
# 1367  LogisticRegression
#
# [418604 rows x 4 columns]

# %%
embedding
# Out:
#                                        ('1', '186347356', 'TPR')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                        0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                        0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                        0.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                        0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                        0.0
# ...                                                          ...
# ALS__CGND-HDA-00553__NEUMK638LUX                             1.0
# ALS__CGND-HDA-00865__MH-WASHU-243                            0.0
# ALS__CGND-HDA-00788__MH-WASHU-166                            1.0
# ALS__CGND-HDA-02291__14-198-02                               0.0
# ALS__CGND-HDA-02334__95-113-46                               0.0
#
#                                        ('1', '225419442', 'LBR')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                        1.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                        1.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                        1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                        1.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                        1.0
# ...                                                          ...
# ALS__CGND-HDA-00553__NEUMK638LUX                             1.0
# ALS__CGND-HDA-00865__MH-WASHU-243                            1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                            1.0
# ALS__CGND-HDA-02291__14-198-02                               1.0
# ALS__CGND-HDA-02334__95-113-46                               1.0
#
#                                        ('1', '229487591', 'NUP133')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                           0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                           0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                           1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                           0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                           0.0
# ...                                                             ...
# ALS__CGND-HDA-00553__NEUMK638LUX                                0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                               0.0
# ALS__CGND-HDA-00788__MH-WASHU-166                               1.0
# ALS__CGND-HDA-02291__14-198-02                                  0.0
# ALS__CGND-HDA-02334__95-113-46                                  0.0
#
#                                        ('1', '229495987', 'NUP133')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                           0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                           0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                           1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                           0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                           0.0
# ...                                                             ...
# ALS__CGND-HDA-00553__NEUMK638LUX                                0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                               0.0
# ALS__CGND-HDA-00788__MH-WASHU-166                               1.0
# ALS__CGND-HDA-02291__14-198-02                                  0.0
# ALS__CGND-HDA-02334__95-113-46                                  0.0
#
#                                        ('1', '246842749', 'AHCTF1')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                           1.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                           0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                           1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                           0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                           0.0
# ...                                                             ...
# ALS__CGND-HDA-00553__NEUMK638LUX                                0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                               1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                               0.0
# ALS__CGND-HDA-02291__14-198-02                                  0.0
# ALS__CGND-HDA-02334__95-113-46                                  1.0
#
#                                        ('1', '246861024', 'AHCTF1')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                           0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                           0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                           0.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                           1.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                           0.0
# ...                                                             ...
# ALS__CGND-HDA-00553__NEUMK638LUX                                0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                               1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                               0.0
# ALS__CGND-HDA-02291__14-198-02                                  0.0
# ALS__CGND-HDA-02334__95-113-46                                  0.0
#
#                                        ('1', '246877229', 'AHCTF1')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                           0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                           0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                           0.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                           0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                           0.0
# ...                                                             ...
# ALS__CGND-HDA-00553__NEUMK638LUX                                0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                               0.0
# ALS__CGND-HDA-00788__MH-WASHU-166                               1.0
# ALS__CGND-HDA-02291__14-198-02                                  0.0
# ALS__CGND-HDA-02334__95-113-46                                  0.0
#
#                                        ('1', '246885532', 'AHCTF1')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                           1.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                           0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                           1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                           0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                           1.0
# ...                                                             ...
# ALS__CGND-HDA-00553__NEUMK638LUX                                1.0
# ALS__CGND-HDA-00865__MH-WASHU-243                               1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                               1.0
# ALS__CGND-HDA-02291__14-198-02                                  1.0
# ALS__CGND-HDA-02334__95-113-46                                  1.0
#
#                                        ('2', '183131001', 'NUP35')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                          0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                          0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                          0.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                          0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                          0.0
# ...                                                            ...
# ALS__CGND-HDA-00553__NEUMK638LUX                               0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                              0.0
# ALS__CGND-HDA-00788__MH-WASHU-166                              1.0
# ALS__CGND-HDA-02291__14-198-02                                 0.0
# ALS__CGND-HDA-02334__95-113-46                                 0.0
#
#                                        ('2', '183131014', 'NUP35')  ...
# id                                                                  ...
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                          0.0  ...  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                          1.0  ...
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                          1.0  ...
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                          1.0  ...
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                          1.0  ...
# ...                                                            ...  ...
# ALS__CGND-HDA-00553__NEUMK638LUX                               1.0  ...
# ALS__CGND-HDA-00865__MH-WASHU-243                              1.0  ...
# ALS__CGND-HDA-00788__MH-WASHU-166                              1.0  ...
# ALS__CGND-HDA-02291__14-198-02                                 1.0  ...
# ALS__CGND-HDA-02334__95-113-46                                 1.0  ...
#
#                                        ('14', '24210671', 'CHMP4A')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                           1.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                           1.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                           1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                           0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                           1.0
# ...                                                             ...
# ALS__CGND-HDA-00553__NEUMK638LUX                                1.0
# ALS__CGND-HDA-00865__MH-WASHU-243                               1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                               1.0
# ALS__CGND-HDA-02291__14-198-02                                  1.0
# ALS__CGND-HDA-02334__95-113-46                                  1.0
#
#                                        ('16', '56839701', 'NUP93')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                          0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                          0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                          1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                          1.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                          0.0
# ...                                                            ...
# ALS__CGND-HDA-00553__NEUMK638LUX                               0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                              0.0
# ALS__CGND-HDA-00788__MH-WASHU-166                              0.0
# ALS__CGND-HDA-02291__14-198-02                                 0.0
# ALS__CGND-HDA-02334__95-113-46                                 0.0
#
#                                        ('16', '71922608', 'IST1')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                         0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                         1.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                         0.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                         1.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                         0.0
# ...                                                           ...
# ALS__CGND-HDA-00553__NEUMK638LUX                              0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                             1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                             1.0
# ALS__CGND-HDA-02291__14-198-02                                0.0
# ALS__CGND-HDA-02334__95-113-46                                0.0
#
#                                        ('16', '71924122', 'IST1')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                         0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                         0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                         0.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                         0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                         0.0
# ...                                                           ...
# ALS__CGND-HDA-00553__NEUMK638LUX                              1.0
# ALS__CGND-HDA-00865__MH-WASHU-243                             1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                             0.0
# ALS__CGND-HDA-02291__14-198-02                                1.0
# ALS__CGND-HDA-02334__95-113-46                                0.0
#
#                                        ('16', '71924149', 'IST1')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                         0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                         1.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                         0.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                         1.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                         0.0
# ...                                                           ...
# ALS__CGND-HDA-00553__NEUMK638LUX                              0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                             1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                             1.0
# ALS__CGND-HDA-02291__14-198-02                                1.0
# ALS__CGND-HDA-02334__95-113-46                                1.0
#
#                                        ('17', '47671806', 'KPNB1')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                          0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                          0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                          1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                          1.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                          1.0
# ...                                                            ...
# ALS__CGND-HDA-00553__NEUMK638LUX                               1.0
# ALS__CGND-HDA-00865__MH-WASHU-243                              1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                              1.0
# ALS__CGND-HDA-02291__14-198-02                                 1.0
# ALS__CGND-HDA-02334__95-113-46                                 1.0
#
#                                        ('18', '12984145', 'SEH1L')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                          0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                          1.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                          1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                          1.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                          0.0
# ...                                                            ...
# ALS__CGND-HDA-00553__NEUMK638LUX                               1.0
# ALS__CGND-HDA-00865__MH-WASHU-243                              1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                              1.0
# ALS__CGND-HDA-02291__14-198-02                                 1.0
# ALS__CGND-HDA-02334__95-113-46                                 1.0
#
#                                        ('19', '7961534', 'ELAVL1')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                          0.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                          0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                          1.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                          0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                          0.0
# ...                                                            ...
# ALS__CGND-HDA-00553__NEUMK638LUX                               0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                              0.0
# ALS__CGND-HDA-00788__MH-WASHU-166                              0.0
# ALS__CGND-HDA-02291__14-198-02                                 0.0
# ALS__CGND-HDA-02334__95-113-46                                 0.0
#
#                                        ('19', '49908960', 'NUP62')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                          1.0  \
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                          1.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                          0.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                          1.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                          0.0
# ...                                                            ...
# ALS__CGND-HDA-00553__NEUMK638LUX                               0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                              1.0
# ALS__CGND-HDA-00788__MH-WASHU-166                              1.0
# ALS__CGND-HDA-02291__14-198-02                                 1.0
# ALS__CGND-HDA-02334__95-113-46                                 1.0
#
#                                        ('19', '58551790', 'CHMP2A')
# id
# aals-ALS__CGND-HDA-04086__NEUDH813DE6                           0.0
# aals-ALS__CGND-HDA-04082__NEUTB997GDW                           0.0
# aals-ALS__CGND-HDA-04081__NEUAD952KAZ                           0.0
# aals-ALS__CGND-HDA-04079__NEUMT573TE9                           0.0
# aals-ALS__CGND-HDA-04069__NEUEA668FYK                           0.0
# ...                                                             ...
# ALS__CGND-HDA-00553__NEUMK638LUX                                0.0
# ALS__CGND-HDA-00865__MH-WASHU-243                               0.0
# ALS__CGND-HDA-00788__MH-WASHU-166                               1.0
# ALS__CGND-HDA-02291__14-198-02                                  0.0
# ALS__CGND-HDA-02334__95-113-46                                  0.0
#
# [2736 rows x 54 columns]

# %%
import plotly.express as px

# Group by sample ID and calculate mean probability for each sample
mean_probs = sampleResults.groupby(['id', 'model'])['probability'].mean().reset_index()

# Create histogram
fig = px.histogram(mean_probs, x='probability', color='model', title="Mean Sample ALS Probability")
fig.show()

# %%
import pickle
import multiprocess as mp

def load_pickled(args):
    field, runID = args
    return pickle.load(open(f'{field}/{runID}.pkl', 'rb'))

def load_fold_dataframe(args):
    field, runID = args
    return pd.concat([pd.read_csv(f'{field}/{runID}_{i}.csv') for i in range(1,11)])

labels = list()
shapExplanations = list()

# Prepare arguments for the load_pickled function
label_args_list = [('testLabels', runID) for runID in sampleResults['run'].unique()]
shap_args_list = [('shapExplanationsPerFold', runID) for runID in sampleResults['run'].unique()]

# Load pickled data using multiprocessing
with mp.Pool(mp.cpu_count() // 2) as pool:
    loadedLabels = pool.map(load_pickled, label_args_list)
    loadedShapValues = pool.map(load_pickled, shap_args_list) 
    assert len(loadedLabels) == len(loadedShapValues)
    # Flatten the loaded data across bootstrap iterations i and crossval folds j
    for i in range(len(loadedLabels)):
        assert len(loadedLabels[i]) == len(loadedShapValues[i])
        for j in range(len(loadedLabels[i])):
            labels.extend(loadedLabels[i][j])
            shapExplanations.extend(loadedShapValues[i][j])

# Update sampleResults DataFrame
sampleResults['label'] = labels
sampleResults['shapExplanations'] = shapExplanations
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/noot/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/noot/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_143869/611611446.py", line 6, in load_pickled
#     return pickle.load(open(f'{field}/{runID}.pkl', 'rb'))
#   File "/home/noot/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 284, in _modified_open
#     return io_open(file, *args, **kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: 'testLabels/NUPNOPARAM-528.pkl'
# """
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 17
#      15 # Load pickled data using multiprocessing
#      16 with mp.Pool(mp.cpu_count() // 2) as pool:
# ---> 17     loadedLabels = pool.map(load_pickled, label_args_list)
#      18     loadedShapValues = pool.map(load_pickled, shap_args_list)
#      19     assert len(loadedLabels) == len(loadedShapValues)
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/multiprocess/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/multiprocess/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testLabels/NUPNOPARAM-528.pkl'

# %% [markdown]
# ## Determine sample accuracy

# %%
import numpy as np
import pandas as pd

# calculate accuracy for each sample, model pair
resolvedSampleResults = []
for id, group in sampleResults.groupby(['id', 'model'], group_keys=False):
    assert len(group['label'].unique()) == 1  # All labels should be the same
    sampleLabel = group['label'].unique()[0]
    sampleClassifications = np.where(group['probability'] >= 0.5, np.ceil(group['probability']), np.floor(group['probability'])) # Scale probablility to label values for direct classification
    group['accuracy'] = np.mean(sampleClassifications == sampleLabel)
    resolvedSampleResults.append(group) 
sampleResults = pd.concat(resolvedSampleResults)
sampleResults_cases = sampleResults[sampleResults['label'] == 1]
sampleResults_controls = sampleResults[sampleResults['label'] == 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 7
#       5 resolvedSampleResults = []
#       6 for id, group in sampleResults.groupby(['id', 'model'], group_keys=False):
# ----> 7     assert len(group['label'].unique()) == 1  # All labels should be the same
#       8     sampleLabel = group['label'].unique()[0]
#       9     sampleClassifications = np.where(group['probability'] >= 0.5, np.ceil(group['probability']), np.floor(group['probability'])) # Scale probablility to label values for direct classification
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/pandas/core/frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'label'

# %%
pd.set_option('display.max_rows', 25)
pd.set_option('display.min_rows', 25)

# %%
sampleResults[[column for column in sampleResults.columns if column not in ['shapExplanations']]]
# Out:
#                                          id  probability             run
# 0     aals-ALS__CGND-HDA-04086__NEUDH813DE6     0.498972  NUPNOPARAM-528  \
# 1     aals-ALS__CGND-HDA-04082__NEUTB997GDW     0.502975  NUPNOPARAM-528
# 2     aals-ALS__CGND-HDA-04081__NEUAD952KAZ     0.498127  NUPNOPARAM-528
# 3     aals-ALS__CGND-HDA-04079__NEUMT573TE9     0.499165  NUPNOPARAM-528
# 4     aals-ALS__CGND-HDA-04069__NEUEA668FYK     0.500982  NUPNOPARAM-528
# ...                                     ...          ...             ...
# 1363                                NA20796     1.000000         NUP-357
# 1364                                NA20804     1.000000         NUP-357
# 1365                                NA20809     1.000000         NUP-357
# 1366                                NA20811     1.000000         NUP-357
# 1367                                NA20828     0.000000         NUP-357
#
#                    model
# 0          XGBClassifier
# 1          XGBClassifier
# 2          XGBClassifier
# 3          XGBClassifier
# 4          XGBClassifier
# ...                  ...
# 1363  LogisticRegression
# 1364  LogisticRegression
# 1365  LogisticRegression
# 1366  LogisticRegression
# 1367  LogisticRegression
#
# [418604 rows x 4 columns]

# %%
import plotly.express as px

# Group by sample ID and label, calculate mean accuracy for each sample
mean_accuracy = sampleResults.groupby(['id', 'model', 'label'])['accuracy'].mean().reset_index()

# Create histogram of mean accuracy
fig = px.histogram(mean_accuracy, x='accuracy', color='label', pattern_shape='label', title="Mean Sample Accuracy")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 4
#       1 import plotly.express as px
#       3 # Group by sample ID and label, calculate mean accuracy for each sample
# ----> 4 mean_accuracy = sampleResults.groupby(['id', 'model', 'label'])['accuracy'].mean().reset_index()
#       6 # Create histogram of mean accuracy
#       7 fig = px.histogram(mean_accuracy, x='accuracy', color='label', pattern_shape='label', title="Mean Sample Accuracy")
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/pandas/core/frame.py:8256, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8253     raise TypeError("You have to supply one of 'by' and 'level'")
#    8254 axis = self._get_axis_number(axis)
# -> 8256 return DataFrameGroupBy(
#    8257     obj=self,
#    8258     keys=by,
#    8259     axis=axis,
#    8260     level=level,
#    8261     as_index=as_index,
#    8262     sort=sort,
#    8263     group_keys=group_keys,
#    8264     observed=observed,
#    8265     dropna=dropna,
#    8266 )
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~/.pyenv/versions/miniconda3-latest/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'label'

# %% [markdown]
# ## Correlate sample accuracy across models
#
# - Use Spearman rank-order method since model accuracies should be monotonic

# %%
accuracy_grouped_models_df = sampleResults.groupby(['id', 'model', 'label'])['accuracy'].mean().reset_index()

# %%
accuracy_grouped_models_df
# Out:
#                                           id                   model  label  \
# 0            ALS__CGND-HDA-00001__UP-WGS-185      AdaBoostClassifier      1
# 1            ALS__CGND-HDA-00001__UP-WGS-185               LinearSVC      1
# 2            ALS__CGND-HDA-00001__UP-WGS-185      LogisticRegression      1
# 3            ALS__CGND-HDA-00001__UP-WGS-185           MultinomialNB      1
# 4            ALS__CGND-HDA-00001__UP-WGS-185          RadialBasisSVC      1
# 5            ALS__CGND-HDA-00001__UP-WGS-185  RandomForestClassifier      1
# 6            ALS__CGND-HDA-00001__UP-WGS-185           XGBClassifier      1
# 7            ALS__CGND-HDA-00004__UP-WGS-187      AdaBoostClassifier      1
# 8            ALS__CGND-HDA-00004__UP-WGS-187               LinearSVC      1
# 9            ALS__CGND-HDA-00004__UP-WGS-187      LogisticRegression      1
# 10           ALS__CGND-HDA-00004__UP-WGS-187           MultinomialNB      1
# 11           ALS__CGND-HDA-00004__UP-WGS-187          RadialBasisSVC      1
# ...                                      ...                     ...    ...
# 19140  aals-CTR__CGND-HDA-03876__NEUXY894VJR      LogisticRegression      0
# 19141  aals-CTR__CGND-HDA-03876__NEUXY894VJR           MultinomialNB      0
# 19142  aals-CTR__CGND-HDA-03876__NEUXY894VJR          RadialBasisSVC      0
# 19143  aals-CTR__CGND-HDA-03876__NEUXY894VJR  RandomForestClassifier      0
# 19144  aals-CTR__CGND-HDA-03876__NEUXY894VJR           XGBClassifier      0
# 19145  aals-CTR__CGND-HDA-03896__NEUNG931UCJ      AdaBoostClassifier      0
# 19146  aals-CTR__CGND-HDA-03896__NEUNG931UCJ               LinearSVC      0
# 19147  aals-CTR__CGND-HDA-03896__NEUNG931UCJ      LogisticRegression      0
# 19148  aals-CTR__CGND-HDA-03896__NEUNG931UCJ           MultinomialNB      0
# 19149  aals-CTR__CGND-HDA-03896__NEUNG931UCJ          RadialBasisSVC      0
# 19150  aals-CTR__CGND-HDA-03896__NEUNG931UCJ  RandomForestClassifier      0
# 19151  aals-CTR__CGND-HDA-03896__NEUNG931UCJ           XGBClassifier      0
#
#        accuracy
# 0      0.500000
# 1      0.500000
# 2      0.478261
# 3      0.600000
# 4      0.400000
# 5      0.409091
# 6      0.619048
# 7      0.777778
# 8      0.882353
# 9      0.933333
# 10     0.800000
# 11     0.809524
# ...         ...
# 19140  0.383333
# 19141  0.416667
# 19142  0.433333
# 19143  0.566667
# 19144  0.416667
# 19145  0.633333
# 19146  0.750000
# 19147  0.783333
# 19148  0.683333
# 19149  0.733333
# 19150  0.816667
# 19151  0.700000
#
# [19152 rows x 4 columns]

# %%
model_case_accuracy_pivot_df = accuracy_grouped_models_df.loc[accuracy_grouped_models_df['label']==1].pivot(index='id', columns='model', values='accuracy')
model_control_accuracy_pivot_df = accuracy_grouped_models_df.loc[accuracy_grouped_models_df['label']==0].pivot(index='id', columns='model', values='accuracy')

# %%
model_control_accuracy_pivot_df
# Out:
# model                                  AdaBoostClassifier  LinearSVC
# id                                                                    \
# CTR__CGND-HDA-00196__NEUHC282LVJ                 0.733333   0.783333
# CTR__CGND-HDA-00209__NEUZW491LJA                 0.200000   0.100000
# CTR__CGND-HDA-00260__NEUCX966RX5                 0.850000   0.900000
# CTR__CGND-HDA-00434__NEUXM830AFG                 0.583333   0.483333
# CTR__CGND-HDA-00435__NEUKZ685AR4                 0.283333   0.250000
# CTR__CGND-HDA-00556__NEUHX090PGV                 0.833333   0.866667
# CTR__CGND-HDA-00564__NEUEG442LDR                 0.383333   0.383333
# CTR__CGND-HDA-00565__NEUEA633EN5                 0.366667   0.233333
# CTR__CGND-HDA-00599__NEUDW867LF9                 0.400000   0.316667
# CTR__CGND-HDA-00997__NEUDD927MAK                 0.233333   0.216667
# CTR__CGND-HDA-01020__NEURK254WN5                 0.500000   0.500000
# CTR__CGND-HDA-01021__NEUAY640UVP                 0.550000   0.450000
# ...                                                   ...        ...
# aals-CTR__CGND-HDA-03588__NEUYA376UJ4            0.116667   0.100000
# aals-CTR__CGND-HDA-03591__NEUMF089KLV            0.116667   0.116667
# [684 rows x 7 columns]

# %%
from scipy.stats import spearmanr

model_accuracy_pivot_df = pd.concat([model_case_accuracy_pivot_df, model_control_accuracy_pivot_df], axis=0)
sample_accuracy_pivot_df = model_accuracy_pivot_df.transpose()
modelAccuracyCorrelation, _ = spearmanr(model_accuracy_pivot_df)
sampleAccuracyCorrelation, _ = spearmanr(sample_accuracy_pivot_df)
modelCorrelation_df = pd.DataFrame(modelAccuracyCorrelation, index=model_accuracy_pivot_df.columns, columns=model_accuracy_pivot_df.columns)
sampleCorrelation_df = pd.DataFrame(sampleAccuracyCorrelation, index=sample_accuracy_pivot_df.columns, columns=sample_accuracy_pivot_df.columns)

modelCaseAccuracyCorrelation, _ = spearmanr(model_case_accuracy_pivot_df)
modelCaseCorrelation_df =  pd.DataFrame(modelCaseAccuracyCorrelation, index=model_case_accuracy_pivot_df.columns, columns=model_case_accuracy_pivot_df.columns)
modelControlAccuracyCorrelation, _ = spearmanr(model_control_accuracy_pivot_df)
modelControlCorrelation_df =  pd.DataFrame(modelControlAccuracyCorrelation, index=model_control_accuracy_pivot_df.columns, columns=model_control_accuracy_pivot_df.columns)

# %%
import plotly.figure_factory as ff

fig = ff.create_annotated_heatmap(z=modelCorrelation_df.values,
                                  x=list(modelCorrelation_df.columns),
                                  y=list(modelCorrelation_df.columns),
                                  annotation_text=modelCorrelation_df.round(2).values,
                                  colorscale='Viridis')
fig.update_layout(title_text='Spearman Correlation of Per-Sample Accuracy Across Models',
                  xaxis = dict(title='Model'),
                  yaxis = dict(title='Model'),
                  margin={'t':175},)
fig.show()

fig = ff.create_annotated_heatmap(z=modelCaseCorrelation_df.values,
                                  x=list(modelCaseCorrelation_df.columns),
                                  y=list(modelCaseCorrelation_df.columns),
                                  annotation_text=modelCorrelation_df.round(2).values,
                                  colorscale='Viridis')
fig.update_layout(title_text='Spearman Correlation of Per-Case Accuracy Across Models',
                  xaxis = dict(title='Model'),
                  yaxis = dict(title='Model'),
                  margin={'t':175},)
fig.show()

fig = ff.create_annotated_heatmap(z=modelControlCorrelation_df.values,
                                  x=list(modelControlCorrelation_df.columns),
                                  y=list(modelControlCorrelation_df.columns),
                                  annotation_text=modelControlCorrelation_df.round(2).values,
                                  colorscale='Viridis')
fig.update_layout(title_text='Spearman Correlation of Per-Control Accuracy Across Models',
                  xaxis = dict(title='Model'),
                  yaxis = dict(title='Model'),
                  margin={'t':175},)
fig.show()

# %% [markdown]
# ## Plot heatmap of variants x cases and variants x controls
#
# - Sort samples by accuracy
# - Color by feature value
#     - Cluster case variants, show dendogram
#     - Order control variants by case clustering too

# %% [markdown]
# ## Select outlier samples in accuracy distribution

# %%
accuracyThreshold = (0.85, 0.15)
accurateSamples = sampleResults[sampleResults['accuracy'] >= accuracyThreshold[0]].groupby(['id', 'label'])['accuracy'].mean().reset_index()
discordantSamples = sampleResults[sampleResults['accuracy'] <= accuracyThreshold[1]].groupby(['id', 'label'])['accuracy'].mean().reset_index()

# %%
print(f"total samples: {sampleResults['id'].unique().shape[0]}")
print(f"cases with classification accuracy above {accuracyThreshold[0]:.0%}: {accurateSamples.loc[accurateSamples['label'] == 1,'id'].unique().shape[0]}")
print(f"controls with classification accuracy above {accuracyThreshold[0]:.0%}: {accurateSamples.loc[accurateSamples['label'] == 0,'id'].unique().shape[0]}")

print(f"cases with classification accuracy above {accuracyThreshold[1]:.0%}: {discordantSamples.loc[discordantSamples['label'] == 1,'id'].unique().shape[0]}")
print(f"controls with classification accuracy above {accuracyThreshold[1]:.0%}: {discordantSamples.loc[discordantSamples['label'] == 0,'id'].unique().shape[0]}")
# Out:
# total samples: 2736
# cases with classification accuracy above 85%: 695
# controls with classification accuracy above 85%: 91
# cases with classification accuracy above 15%: 410
# controls with classification accuracy above 15%: 146

# %%
accurateSamples[[column for column in accurateSamples.columns if column not in ['shapExplanations']]]
# Out:
#                                         id  label  accuracy
# 0          ALS__CGND-HDA-00004__UP-WGS-187      1  0.906250
# 1          ALS__CGND-HDA-00012__UP-WGS-195      1  0.906250
# 2          ALS__CGND-HDA-00013__UP-WGS-196      1  0.866667
# 3          ALS__CGND-HDA-00028__UP-WGS-211      1  0.915254
# 4          ALS__CGND-HDA-00051__UP-WGS-234      1  0.888889
# 5          ALS__CGND-HDA-00057__UP-WGS-241      1  0.920635
# 6          ALS__CGND-HDA-00064__UP-WGS-248      1  0.956522
# 7          ALS__CGND-HDA-00076__UP-WGS-260      1  0.882353
# 8          ALS__CGND-HDA-00101__UP-WGS-285      1  0.895349
# 9          ALS__CGND-HDA-00102__UP-WGS-286      1  0.868852
# 10         ALS__CGND-HDA-00111__UP-WGS-296      1  0.926829
# 11         ALS__CGND-HDA-00135__UP-WGS-320      1  0.933333
# ..                                     ...    ...       ...
# 774  aals-ALS__CGND-HDA-04069__NEUEA668FYK      1  0.913043
# 775  aals-ALS__CGND-HDA-04071__NEUCD063FGD      1  0.950000
# 776  aals-ALS__CGND-HDA-04075__NEUZA643DHA      1  0.875776
# 777  aals-ALS__CGND-HDA-04077__NEUAT541XCN      1  0.916667
# 778  aals-ALS__CGND-HDA-04078__NEUTE443RWG      1  0.886792
# 779  aals-ALS__CGND-HDA-04086__NEUDH813DE6      1  0.857143
# 780  aals-ALS__CGND-HDA-04089__NEUEU419NMF      1  0.926230
# 781  aals-CTR__CGND-HDA-03089__NEUGW842RG3      0  0.850000
# 782  aals-CTR__CGND-HDA-03142__NEURJ861MMD      0  0.893333
# 783  aals-CTR__CGND-HDA-03201__NEUWD043UBM      0  0.858333
# 784  aals-CTR__CGND-HDA-03584__NEUEB210XRC      0  0.876667
# 785  aals-CTR__CGND-HDA-03597__NEUBU578NX3      0  0.850000
#
# [786 rows x 3 columns]

# %% [markdown]
# ## View variants by sample accuracy

# %%
accurateCases
# Out:
#                                        label  accuracy
# id
# ALS__CGND-HDA-01215__NEUUA360BR1           1      1.00
# ALS__CGND-HDA-03062__UP-WGS-535            1      1.00
# ALS__CGND-HDA-02741__PF-UCL-28             1      1.00
# ALS__CGND-HDA-00353__358ALS                1      1.00
# ALS__CGND-HDA-01013__NEUFL908GEL           1      1.00
# ALS__CGND-HDA-00872__MH-WASHU-250          1      1.00
# ALS__CGND-HDA-01813__TD-ALS-136            1      1.00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV
0
# ALS__CGND-HDA-01298__EC21                                       1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                1.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 1.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  1.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           1.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           1.0
# ALS__CGND-HDA-00357__819ALS                                     1.0
#
#                                        ('2', '183131001', 'NUP35')
# id                                                                  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                 0.0
# ALS__CGND-HDA-00353__358ALS                                    0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                               1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                              0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                1.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          1.0
# ALS__CGND-HDA-00644__MH-WASHU-22                               1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                               1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              0.0
# ...                                                            ...
# ALS__CGND-HDA-00290__2067ALS                                   0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                               0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                0.0
# ALS__CGND-HDA-01298__EC21                                      1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                               1.0
# ALS__CGND-HDA-02639__UP-WGS-394                                0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                 0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                               0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          1.0
# ALS__CGND-HDA-00357__819ALS                                    0.0
#
#                                        ('2', '183131014', 'NUP35')  ...
# id                                                                  ...  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               1.0  ...
# ALS__CGND-HDA-03062__UP-WGS-535                                1.0  ...
# ALS__CGND-HDA-02741__PF-UCL-28                                 1.0  ...
# ALS__CGND-HDA-00353__358ALS                                    1.0  ...
# ALS__CGND-HDA-01013__NEUFL908GEL                               1.0  ...
# ALS__CGND-HDA-00872__MH-WASHU-250                              1.0  ...
# ALS__CGND-HDA-01813__TD-ALS-136                                1.0  ...
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          1.0  ...
# ALS__CGND-HDA-00644__MH-WASHU-22                               1.0  ...
# ALS__CGND-HDA-03505__NEUBA645MFF                               1.0  ...
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          1.0  ...
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              1.0  ...
# ...                                                            ...  ...
# ALS__CGND-HDA-00290__2067ALS                                   1.0  ...
# ALS__CGND-HDA-03508__NEUBP660ENV                               1.0  ...
# ALS__CGND-HDA-02615__UP-WGS-370                                1.0  ...
# ALS__CGND-HDA-01298__EC21                                      1.0  ...
# ALS__CGND-HDA-03409__NEUXD612TBW                               1.0  ...
# ALS__CGND-HDA-02639__UP-WGS-394                                1.0  ...
# ALS__CGND-HDA-03033__UP-WGS-506                                1.0  ...
# ALS__CGND-HDA-01751__TD-ALS-20                                 1.0  ...
# ALS__CGND-HDA-04032__NEUJY975TFA                               1.0  ...
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          1.0  ...
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          1.0  ...
# ALS__CGND-HDA-00357__819ALS                                    1.0  ...
#
#                                        ('14', '24210671', 'CHMP4A')
# id                                                                   \
# ALS__CGND-HDA-01215__NEUUA360BR1                                1.0
# ALS__CGND-HDA-03062__UP-WGS-535                                 0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                  0.0
# ALS__CGND-HDA-00353__358ALS                                     0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                                0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                               0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                 0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                           1.0
# ALS__CGND-HDA-00644__MH-WASHU-22                                0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                                1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                           1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                               1.0
# ...                                                             ...
# ALS__CGND-HDA-00290__2067ALS                                    0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                                0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                 0.0
# ALS__CGND-HDA-01298__EC21                                       1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                1.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  1.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           1.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           1.0
# ALS__CGND-HDA-00357__819ALS                                     1.0
#
#                                        ('16', '56839701', 'NUP93')
# id                                                                  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                 1.0
# ALS__CGND-HDA-00353__358ALS                                    0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                               0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                              0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                               1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                               0.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              0.0
# ...                                                            ...
# ALS__CGND-HDA-00290__2067ALS                                   0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                               1.0
# ALS__CGND-HDA-02615__UP-WGS-370                                0.0
# ALS__CGND-HDA-01298__EC21                                      0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                               0.0
# ALS__CGND-HDA-02639__UP-WGS-394                                0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                 0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                               0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          1.0
# ALS__CGND-HDA-00357__819ALS                                    0.0
#
#                                        ('16', '71922608', 'IST1')
# id                                                                 \
# ALS__CGND-HDA-01215__NEUUA360BR1                              0.0
# ALS__CGND-HDA-03062__UP-WGS-535                               1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                1.0
# ALS__CGND-HDA-00353__358ALS                                   0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                              1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                             0.0
# ALS__CGND-HDA-01813__TD-ALS-136                               0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                         0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                              0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                              0.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                         0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                             0.0
# ...                                                           ...
# ALS__CGND-HDA-00290__2067ALS                                  1.0
# ALS__CGND-HDA-03508__NEUBP660ENV                              0.0
# ALS__CGND-HDA-02615__UP-WGS-370                               0.0
# ALS__CGND-HDA-01298__EC21                                     0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                              1.0
# ALS__CGND-HDA-02639__UP-WGS-394                               0.0
# ALS__CGND-HDA-03033__UP-WGS-506                               1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                              0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                         0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                         1.0
# ALS__CGND-HDA-00357__819ALS                                   1.0
#
#                                        ('16', '71924122', 'IST1')
# id                                                                 \
# ALS__CGND-HDA-01215__NEUUA360BR1                              0.0
# ALS__CGND-HDA-03062__UP-WGS-535                               0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                1.0
# ALS__CGND-HDA-00353__358ALS                                   0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                              0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                             1.0
# ALS__CGND-HDA-01813__TD-ALS-136                               1.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                         0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                              0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                              1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                         0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                             1.0
# ...                                                           ...
# ALS__CGND-HDA-00290__2067ALS                                  0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                              1.0
# ALS__CGND-HDA-02615__UP-WGS-370                               1.0
# ALS__CGND-HDA-01298__EC21                                     0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                              0.0
# ALS__CGND-HDA-02639__UP-WGS-394                               1.0
# ALS__CGND-HDA-03033__UP-WGS-506                               0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                              1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                         0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                         0.0
# ALS__CGND-HDA-00357__819ALS                                   0.0
#
#                                        ('16', '71924149', 'IST1')
# id                                                                 \
# ALS__CGND-HDA-01215__NEUUA360BR1                              0.0
# ALS__CGND-HDA-03062__UP-WGS-535                               1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                0.0
# ALS__CGND-HDA-00353__358ALS                                   1.0
# ALS__CGND-HDA-01013__NEUFL908GEL                              1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                             1.0
# ALS__CGND-HDA-01813__TD-ALS-136                               0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                         1.0
# ALS__CGND-HDA-00644__MH-WASHU-22                              0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                              0.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                         0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                             1.0
# ...                                                           ...
# ALS__CGND-HDA-00290__2067ALS                                  0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                              0.0
# ALS__CGND-HDA-02615__UP-WGS-370                               0.0
# ALS__CGND-HDA-01298__EC21                                     0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                              0.0
# ALS__CGND-HDA-02639__UP-WGS-394                               1.0
# ALS__CGND-HDA-03033__UP-WGS-506                               0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                              0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                         0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                         0.0
# ALS__CGND-HDA-00357__819ALS                                   0.0
#
#                                        ('17', '47671806', 'KPNB1')
# id                                                                  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               1.0
# ALS__CGND-HDA-03062__UP-WGS-535                                1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                 1.0
# ALS__CGND-HDA-00353__358ALS                                    1.0
# ALS__CGND-HDA-01013__NEUFL908GEL                               1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                              1.0
# ALS__CGND-HDA-01813__TD-ALS-136                                1.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          1.0
# ALS__CGND-HDA-00644__MH-WASHU-22                               1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                               1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              0.0
# ...                                                            ...
# ALS__CGND-HDA-00290__2067ALS                                   0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                               0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                0.0
# ALS__CGND-HDA-01298__EC21                                      1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                               1.0
# ALS__CGND-HDA-02639__UP-WGS-394                                1.0
# ALS__CGND-HDA-03033__UP-WGS-506                                1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                 1.0
# ALS__CGND-HDA-04032__NEUJY975TFA                               1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          1.0
# ALS__CGND-HDA-00357__819ALS                                    1.0
#
#                                        ('18', '12984145', 'SEH1L')
# id                                                                  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               1.0
# ALS__CGND-HDA-03062__UP-WGS-535                                1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                 1.0
# ALS__CGND-HDA-00353__358ALS                                    1.0
# ALS__CGND-HDA-01013__NEUFL908GEL                               1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                              1.0
# ALS__CGND-HDA-01813__TD-ALS-136                                1.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          1.0
# ALS__CGND-HDA-00644__MH-WASHU-22                               1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                               1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              1.0
# ...                                                            ...
# ALS__CGND-HDA-00290__2067ALS                                   1.0
# ALS__CGND-HDA-03508__NEUBP660ENV                               1.0
# ALS__CGND-HDA-02615__UP-WGS-370                                1.0
# ALS__CGND-HDA-01298__EC21                                      1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                               1.0
# ALS__CGND-HDA-02639__UP-WGS-394                                1.0
# ALS__CGND-HDA-03033__UP-WGS-506                                1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                 1.0
# ALS__CGND-HDA-04032__NEUJY975TFA                               1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          1.0
# ALS__CGND-HDA-00357__819ALS                                    1.0
#
#                                        ('19', '7961534', 'ELAVL1')
# id                                                                  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               1.0
# ALS__CGND-HDA-03062__UP-WGS-535                                1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                 0.0
# ALS__CGND-HDA-00353__358ALS                                    0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                               1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                              0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                               0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                               1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              0.0
# ...                                                            ...
# ALS__CGND-HDA-00290__2067ALS                                   0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                               0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                0.0
# ALS__CGND-HDA-01298__EC21                                      0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                               0.0
# ALS__CGND-HDA-02639__UP-WGS-394                                1.0
# ALS__CGND-HDA-03033__UP-WGS-506                                0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                 0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                               1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          0.0
# ALS__CGND-HDA-00357__819ALS                                    0.0
#
#                                        ('19', '49908960', 'NUP62')
# id                                                                  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                 1.0
# ALS__CGND-HDA-00353__358ALS                                    0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                               1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                              1.0
# ALS__CGND-HDA-01813__TD-ALS-136                                0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                               0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                               1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              1.0
# ...                                                            ...
# ALS__CGND-HDA-00290__2067ALS                                   1.0
# ALS__CGND-HDA-03508__NEUBP660ENV                               1.0
# ALS__CGND-HDA-02615__UP-WGS-370                                1.0
# ALS__CGND-HDA-01298__EC21                                      0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                               1.0
# ALS__CGND-HDA-02639__UP-WGS-394                                0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                 0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                               1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          1.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          1.0
# ALS__CGND-HDA-00357__819ALS                                    1.0
#
#                                        ('19', '58551790', 'CHMP2A')
# id
# ALS__CGND-HDA-01215__NEUUA360BR1                                0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                 0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                  0.0
# ALS__CGND-HDA-00353__358ALS                                     0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                                0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                               0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                 0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                           0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                                0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                                1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                           1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                               0.0
# ...                                                             ...
# ALS__CGND-HDA-00290__2067ALS                                    0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                                0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                 0.0
# ALS__CGND-HDA-01298__EC21                                       0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                0.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           0.0
# ALS__CGND-HDA-00357__819ALS                                     0.0
#
# [695 rows x 54 columns]

# %%
topVariants
# Out:
# ["('6', '17675015', 'NUP153')",
#  "('7', '849532', 'SUN1')",
#  "('7', '135584907', 'NUP205')",
#  "('2', '183131014', 'NUP35')",
#  "('3', '13319787', 'NUP210')",
#  "('3', '13353975', 'NUP210')",
#  "('18', '12984145', 'SEH1L')",
#  "('7', '135607350', 'NUP205')",
#  "('1', '246842749', 'AHCTF1')",
#  "('7', '842031', 'SUN1')"]

# %%
outlierCaseEmbeddings.index
# Out:
# Index(['ALS__CGND-HDA-01215__NEUUA360BR1', 'ALS__CGND-HDA-00644__MH-WASHU-22',
#        'ALS__CGND-HDA-03062__UP-WGS-535', 'ALS__CGND-HDA-02651__UP-WGS-406',
#        'aals-ALS__CGND-HDA-03814__NEUCH829YF0',
#        'ALS__CGND-HDA-03630__NSTNNXTLA8ZQ',
#        'aals-ALS__CGND-HDA-03913__NEUJA497KXF',
#        'ALS__CGND-HDA-03505__NEUBA645MFF',
#        'aals-ALS__CGND-HDA-04067__NEUJA207UUV',
#        'ALS__CGND-HDA-01813__TD-ALS-136',
#        ...
#        'ALS__CGND-HDA-02288__13-190-33', 'ALS__CGND-HDA-02561__93-094-34',
#        'aals-ALS__CGND-HDA-02700__NEUPP607CPW',
#        'aals-ALS__CGND-HDA-00234__NEUZN836GME',
#        'ALS__CGND-HDA-02422__03-151-16',
#        'aals-ALS__CGND-HDA-03560__NEUET719NJD',
#        'ALS__CGND-HDA-03442__NEUYU889EY1', 'ALS__CGND-HDA-01795__TD-ALS-87',
#        'ALS__CGND-HDA-03696__NEUBZ354DBH',
#        'aals-ALS__CGND-HDA-03605__NEUPJ681DUM'],
#       dtype='object', name='id', length=1105)

# %%
import dash_bio

accurateCases = accurateSamples.loc[accurateSamples['label'] == 1].sort_values(by=['accuracy'], ascending=False).set_index('id', drop=True)
accurateCaseEmbeddings = embedding.loc[embedding.index.isin(accurateCases.index)].reindex(accurateCases.index)
accurateControls = accurateSamples.loc[accurateSamples['label'] == 0].sort_values(by=['accuracy'], ascending=False).set_index('id', drop=True)
accurateControlEmbeddings = embedding.loc[embedding.index.isin(accurateControls.index)].reindex(accurateControls.index)

discordantCases = discordantSamples.loc[discordantSamples['label'] == 1].sort_values(by=['accuracy'], ascending=False).set_index('id', drop=True)
discordantCaseEmbeddings = embedding.loc[embedding.index.isin(discordantCases.index)].reindex(discordantCases.index)
discordantControls = discordantSamples.loc[discordantSamples['label'] == 0].sort_values(by=['accuracy'], ascending=False).set_index('id', drop=True)
discordantControlEmbeddings = embedding.loc[embedding.index.isin(discordantControls.index)].reindex(discordantControls.index)

outlierCases = pd.concat([accurateCases, discordantCases]).sort_values(by=['accuracy'], ascending=False)
outlierCaseEmbeddings = embedding.loc[embedding.index.isin(outlierCases.index)].reindex(outlierCases.index)

outlierControls = pd.concat([accurateControls, discordantControls]).sort_values(by=['accuracy'], ascending=False)
outlierControlEmbeddings = embedding.loc[embedding.index.isin(outlierControls.index)].reindex(outlierControls.index)

outlierSamples = pd.concat([accurateSamples, discordantSamples]).sort_values(by=['accuracy'], ascending=False)
outlierEmbeddings = embedding.loc[embedding.index.isin(outlierSamples.index)].reindex(outlierSamples.index)

topVariants = averageCaseGlobalFeatureImportances.iloc[:10].index
outlierCaseEmbeddings = outlierCaseEmbeddings[topVariants]
outlierControlEmbeddings = outlierControlEmbeddings[topVariants]


plot = dash_bio.Clustergram(
    data=outlierCaseEmbeddings.T.values,
    row_labels=list(outlierCaseEmbeddings.columns.values),
    column_labels=list(outlierCaseEmbeddings.index),
    hidden_labels='column',
    cluster='row',
    height=1200,
    width=1200,
    color_map= [
        [0.0, '#636EFA'],
        [0.25, '#AB63FA'],
        [0.5, '#FFFFFF'],
        [0.75, '#E763FA'],
        [1.0, '#EF553B']
    ])
plot.update_layout(title={'text': 'Outlier Case Variants (Accuracy >= 85% or <= 15%, highest on left)', 'x': 0.5, 'xanchor': 'center'})
plot.write_html('outlier_cases_clustergram.html')

# TODO filter important variants 
plot = dash_bio.Clustergram(
    data=outlierControlEmbeddings.T.values,
    row_labels=list(outlierControlEmbeddings.columns.values),
    column_labels=list(outlierControlEmbeddings.index),
    hidden_labels='column',
    cluster='row',
    height=1200,
    width=1200,
    color_map= [
        [0.0, '#636EFA'],
        [0.25, '#AB63FA'],
        [0.5, '#FFFFFF'],
        [0.75, '#E763FA'],
        [1.0, '#EF553B']
    ])
plot.update_layout(title={'text': 'Outlier Control Variants (Accuracy >= 85% or <= 15%, highest on left)', 'x': 0.5, 'xanchor': 'center'})
plot.write_html('outlier_controls_clustergram.html')

plot = dash_bio.Clustergram(
    data=embedding.T.values,
    row_labels=list(embedding.columns.values),
    column_labels=list(embedding.index),
    hidden_labels='column',
    cluster='row',
    height=1200,
    width=1200,
    color_map= [
        [0.0, '#636EFA'],
        [0.25, '#AB63FA'],
        [0.5, '#FFFFFF'],
        [0.75, '#E763FA'],
        [1.0, '#EF553B']
    ])
plot.update_layout(title={'text': 'Outlier Case & Control Variants (Accuracy >= 85% or <= 15%, highest on left)', 'x': 0.5, 'xanchor': 'center'})
plot.write_html('outliers_clustergram.html')

# %%
plot = dash_bio.Clustergram(
    data=discordantCaseEmbeddings.T.values,
    row_labels=list(discordantCaseEmbeddings.columns.values),
    column_labels=list(discordantCaseEmbeddings.index),
    hidden_labels='column',
    cluster='row',
    height=1200,
    width=1200,
    color_map= [
        [0.0, '#636EFA'],
        [0.25, '#AB63FA'],
        [0.5, '#FFFFFF'],
        [0.75, '#E763FA'],
        [1.0, '#EF553B']
    ])
plot.update_layout(title={'text': 'Discordant Case Variants (Accuracy <= 15%, highest on left)', 'x': 0.5, 'xanchor': 'center'})
plot.write_html('discordant_cases_clustergram.html')

plot = dash_bio.Clustergram(
    data=discordantControlEmbeddings.T.values,
    row_labels=list(discordantControlEmbeddings.columns.values),
    column_labels=list(discordantControlEmbeddings.index),
    hidden_labels='column',
    cluster='row',
    height=1200,
    width=1200,
    color_map= [
        [0.0, '#636EFA'],
        [0.25, '#AB63FA'],
        [0.5, '#FFFFFF'],
        [0.75, '#E763FA'],
        [1.0, '#EF553B']
    ])
plot.update_layout(title={'text': 'Discordant Control Variants (Accuracy <= 15%, highest on left)', 'x': 0.5, 'xanchor': 'center'})
plot.write_html('discordant_controls_clustergram.html')

# %%
accurateCaseEmbeddings
# Out:
#                                        ('1', '186347356', 'TPR')
# id                                                                \
# ALS__CGND-HDA-01215__NEUUA360BR1                             0.0
# ALS__CGND-HDA-03062__UP-WGS-535                              0.0
# ALS__CGND-HDA-02741__PF-UCL-28                               0.0
# ALS__CGND-HDA-00353__358ALS                                  0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                             0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                            0.0
# ALS__CGND-HDA-01813__TD-ALS-136                              0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                        0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                             1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                             1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                        0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                            1.0
# ...                                                          ...
# ALS__CGND-HDA-00290__2067ALS                                 0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                             0.0
# ALS__CGND-HDA-02615__UP-WGS-370                              0.0
# ALS__CGND-HDA-01298__EC21                                    0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                             1.0
# ALS__CGND-HDA-02639__UP-WGS-394                              0.0
# ALS__CGND-HDA-03033__UP-WGS-506                              0.0
# ALS__CGND-HDA-01751__TD-ALS-20                               0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                             1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                        0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                        0.0
# ALS__CGND-HDA-00357__819ALS                                  1.0
#
#                                        ('1', '225419442', 'LBR')
# id                                                                \
# ALS__CGND-HDA-01215__NEUUA360BR1                             1.0
# ALS__CGND-HDA-03062__UP-WGS-535                              1.0
# ALS__CGND-HDA-02741__PF-UCL-28                               1.0
# ALS__CGND-HDA-00353__358ALS                                  1.0
# ALS__CGND-HDA-01013__NEUFL908GEL                             1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                            1.0
# ALS__CGND-HDA-01813__TD-ALS-136                              1.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                        1.0
# ALS__CGND-HDA-00644__MH-WASHU-22                             1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                             1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                        1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                            1.0
# ...                                                          ...
# ALS__CGND-HDA-00290__2067ALS                                 1.0
# ALS__CGND-HDA-03508__NEUBP660ENV                             1.0
# ALS__CGND-HDA-02615__UP-WGS-370                              1.0
# ALS__CGND-HDA-01298__EC21                                    1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                             1.0
# ALS__CGND-HDA-02639__UP-WGS-394                              1.0
# ALS__CGND-HDA-03033__UP-WGS-506                              1.0
# ALS__CGND-HDA-01751__TD-ALS-20                               1.0
# ALS__CGND-HDA-04032__NEUJY975TFA                             1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                        1.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                        1.0
# ALS__CGND-HDA-00357__819ALS                                  1.0
#
#                                        ('1', '229487591', 'NUP133')
# id                                                                   \
# ALS__CGND-HDA-01215__NEUUA360BR1                                1.0
# ALS__CGND-HDA-03062__UP-WGS-535                                 1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                  0.0
# ALS__CGND-HDA-00353__358ALS                                     0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                                0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                               1.0
# ALS__CGND-HDA-01813__TD-ALS-136                                 0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                           0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                                0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                                1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                           1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                               0.0
# ...                                                             ...
# ALS__CGND-HDA-00290__2067ALS                                    0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                                0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                 0.0
# ALS__CGND-HDA-01298__EC21                                       1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                0.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           1.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           1.0
# ALS__CGND-HDA-00357__819ALS                                     0.0
#
#                                        ('1', '229495987', 'NUP133')
# id                                                                   \
# ALS__CGND-HDA-01215__NEUUA360BR1                                1.0
# ALS__CGND-HDA-03062__UP-WGS-535                                 1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                  0.0
# ALS__CGND-HDA-00353__358ALS                                     0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                                0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                               1.0
# ALS__CGND-HDA-01813__TD-ALS-136                                 0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                           0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                                0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                                1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                           1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                               0.0
# ...                                                             ...
# ALS__CGND-HDA-00290__2067ALS                                    0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                                0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                 0.0
# ALS__CGND-HDA-01298__EC21                                       1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                0.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           1.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           1.0
# ALS__CGND-HDA-00357__819ALS                                     0.0
#
#                                        ('1', '246842749', 'AHCTF1')
# id                                                                   \
# ALS__CGND-HDA-01215__NEUUA360BR1                                0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                 0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                  1.0
# ALS__CGND-HDA-00353__358ALS                                     0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                                0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                               0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                 0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                           0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                                1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                                0.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                           1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                               1.0
# ...                                                             ...
# ALS__CGND-HDA-00290__2067ALS                                    1.0
# ALS__CGND-HDA-03508__NEUBP660ENV                                1.0
# ALS__CGND-HDA-02615__UP-WGS-370                                 0.0
# ALS__CGND-HDA-01298__EC21                                       0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                0.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  1.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           0.0
# ALS__CGND-HDA-00357__819ALS                                     0.0
#
#                                        ('1', '246861024', 'AHCTF1')
# id                                                                   \
# ALS__CGND-HDA-01215__NEUUA360BR1                                0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                 0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                  0.0
# ALS__CGND-HDA-00353__358ALS                                     0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                                0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                               0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                 0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                           0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                                0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                                0.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                           0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                               0.0
# ...                                                             ...
# ALS__CGND-HDA-00290__2067ALS                                    0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                                0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                 0.0
# ALS__CGND-HDA-01298__EC21                                       0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                0.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           1.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           0.0
# ALS__CGND-HDA-00357__819ALS                                     0.0
#
#                                        ('1', '246877229', 'AHCTF1')
# id                                                                   \
# ALS__CGND-HDA-01215__NEUUA360BR1                                0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                 0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                  0.0
# ALS__CGND-HDA-00353__358ALS                                     0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                                0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                               0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                 0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                           0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                                0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                                0.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                           0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                               0.0
# ...                                                             ...
# ALS__CGND-HDA-00290__2067ALS                                    0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                                0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                 0.0
# ALS__CGND-HDA-01298__EC21                                       1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                0.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           1.0
# ALS__CGND-HDA-00357__819ALS                                     1.0
#
#                                        ('1', '246885532', 'AHCTF1')
# id                                                                   \
# ALS__CGND-HDA-01215__NEUUA360BR1                                0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                 1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                  1.0
# ALS__CGND-HDA-00353__358ALS                                     1.0
# ALS__CGND-HDA-01013__NEUFL908GEL                                1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                               1.0
# ALS__CGND-HDA-01813__TD-ALS-136                                 0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                           1.0
# ALS__CGND-HDA-00644__MH-WASHU-22                                1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                                1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                           1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                               1.0
# ...                                                             ...
# ALS__CGND-HDA-00290__2067ALS                                    1.0
# ALS__CGND-HDA-03508__NEUBP660ENV                                1.0
# ALS__CGND-HDA-02615__UP-WGS-370                                 1.0
# ALS__CGND-HDA-01298__EC21                                       1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                1.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 1.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  1.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           1.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           1.0
# ALS__CGND-HDA-00357__819ALS                                     1.0
#
#                                        ('2', '183131001', 'NUP35')
# id                                                                  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                 0.0
# ALS__CGND-HDA-00353__358ALS                                    0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                               1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                              0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                1.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          1.0
# ALS__CGND-HDA-00644__MH-WASHU-22                               1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                               1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              0.0
# ...                                                            ...
# ALS__CGND-HDA-00290__2067ALS                                   0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                               0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                0.0
# ALS__CGND-HDA-01298__EC21                                      1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                               1.0
# ALS__CGND-HDA-02639__UP-WGS-394                                0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                 0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                               0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          1.0
# ALS__CGND-HDA-00357__819ALS                                    0.0
#
#                                        ('2', '183131014', 'NUP35')  ...
# id                                                                  ...  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               1.0  ...
# ALS__CGND-HDA-03062__UP-WGS-535                                1.0  ...
# ALS__CGND-HDA-02741__PF-UCL-28                                 1.0  ...
# ALS__CGND-HDA-00353__358ALS                                    1.0  ...
# ALS__CGND-HDA-01013__NEUFL908GEL                               1.0  ...
# ALS__CGND-HDA-00872__MH-WASHU-250                              1.0  ...
# ALS__CGND-HDA-01813__TD-ALS-136                                1.0  ...
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          1.0  ...
# ALS__CGND-HDA-00644__MH-WASHU-22                               1.0  ...
# ALS__CGND-HDA-03505__NEUBA645MFF                               1.0  ...
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          1.0  ...
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              1.0  ...
# ...                                                            ...  ...
# ALS__CGND-HDA-00290__2067ALS                                   1.0  ...
# ALS__CGND-HDA-03508__NEUBP660ENV                               1.0  ...
# ALS__CGND-HDA-02615__UP-WGS-370                                1.0  ...
# ALS__CGND-HDA-01298__EC21                                      1.0  ...
# ALS__CGND-HDA-03409__NEUXD612TBW                               1.0  ...
# ALS__CGND-HDA-02639__UP-WGS-394                                1.0  ...
# ALS__CGND-HDA-03033__UP-WGS-506                                1.0  ...
# ALS__CGND-HDA-01751__TD-ALS-20                                 1.0  ...
# ALS__CGND-HDA-04032__NEUJY975TFA                               1.0  ...
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          1.0  ...
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          1.0  ...
# ALS__CGND-HDA-00357__819ALS                                    1.0  ...
#
#                                        ('14', '24210671', 'CHMP4A')
# id                                                                   \
# ALS__CGND-HDA-01215__NEUUA360BR1                                1.0
# ALS__CGND-HDA-03062__UP-WGS-535                                 0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                  0.0
# ALS__CGND-HDA-00353__358ALS                                     0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                                0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                               0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                 0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                           1.0
# ALS__CGND-HDA-00644__MH-WASHU-22                                0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                                1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                           1.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                               1.0
# ...                                                             ...
# ALS__CGND-HDA-00290__2067ALS                                    0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                                0.0
# ALS__CGND-HDA-02615__UP-WGS-370                                 0.0
# ALS__CGND-HDA-01298__EC21                                       1.0
# ALS__CGND-HDA-03409__NEUXD612TBW                                1.0
# ALS__CGND-HDA-02639__UP-WGS-394                                 0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                 1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                  1.0
# ALS__CGND-HDA-04032__NEUJY975TFA                                1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           1.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           1.0
# ALS__CGND-HDA-00357__819ALS                                     1.0
#
#                                        ('16', '56839701', 'NUP93')
# id                                                                  \
# ALS__CGND-HDA-01215__NEUUA360BR1                               0.0
# ALS__CGND-HDA-03062__UP-WGS-535                                1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                 1.0
# ALS__CGND-HDA-00353__358ALS                                    0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                               0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                              0.0
# ALS__CGND-HDA-01813__TD-ALS-136                                0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                          0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                               1.0
# ALS__CGND-HDA-03505__NEUBA645MFF                               0.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                          0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                              0.0
# ...                                                            ...
# ALS__CGND-HDA-00290__2067ALS                                   0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                               1.0
# ALS__CGND-HDA-02615__UP-WGS-370                                0.0
# ALS__CGND-HDA-01298__EC21                                      0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                               0.0
# ALS__CGND-HDA-02639__UP-WGS-394                                0.0
# ALS__CGND-HDA-03033__UP-WGS-506                                0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                 0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                               0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                          0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                          1.0
# ALS__CGND-HDA-00357__819ALS                                    0.0
#
#                                        ('16', '71922608', 'IST1')
# id                                                                 \
# ALS__CGND-HDA-01215__NEUUA360BR1                              0.0
# ALS__CGND-HDA-03062__UP-WGS-535                               1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                1.0
# ALS__CGND-HDA-00353__358ALS                                   0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                              1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                             0.0
# ALS__CGND-HDA-01813__TD-ALS-136                               0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                         0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                              0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                              0.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                         0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                             0.0
# ...                                                           ...
# ALS__CGND-HDA-00290__2067ALS                                  1.0
# ALS__CGND-HDA-03508__NEUBP660ENV                              0.0
# ALS__CGND-HDA-02615__UP-WGS-370                               0.0
# ALS__CGND-HDA-01298__EC21                                     0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                              1.0
# ALS__CGND-HDA-02639__UP-WGS-394                               0.0
# ALS__CGND-HDA-03033__UP-WGS-506                               1.0
# ALS__CGND-HDA-01751__TD-ALS-20                                0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                              0.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                         0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                         1.0
# ALS__CGND-HDA-00357__819ALS                                   1.0
#
#                                        ('16', '71924122', 'IST1')
# id                                                                 \
# ALS__CGND-HDA-01215__NEUUA360BR1                              0.0
# ALS__CGND-HDA-03062__UP-WGS-535                               0.0
# ALS__CGND-HDA-02741__PF-UCL-28                                1.0
# ALS__CGND-HDA-00353__358ALS                                   0.0
# ALS__CGND-HDA-01013__NEUFL908GEL                              0.0
# ALS__CGND-HDA-00872__MH-WASHU-250                             1.0
# ALS__CGND-HDA-01813__TD-ALS-136                               1.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV                         0.0
# ALS__CGND-HDA-00644__MH-WASHU-22                              0.0
# ALS__CGND-HDA-03505__NEUBA645MFF                              1.0
# aals-ALS__CGND-HDA-03913__NEUJA497KXF                         0.0
# ALS__CGND-HDA-03630__NSTNNXTLA8ZQ                             1.0
# ...                                                           ...
# ALS__CGND-HDA-00290__2067ALS                                  0.0
# ALS__CGND-HDA-03508__NEUBP660ENV                              1.0
# ALS__CGND-HDA-02615__UP-WGS-370                               1.0
# ALS__CGND-HDA-01298__EC21                                     0.0
# ALS__CGND-HDA-03409__NEUXD612TBW                              0.0
# ALS__CGND-HDA-02639__UP-WGS-394                               1.0
# ALS__CGND-HDA-03033__UP-WGS-506                               0.0
# ALS__CGND-HDA-01751__TD-ALS-20                                0.0
# ALS__CGND-HDA-04032__NEUJY975TFA                              1.0
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                         0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                         0.0
# ALS__CGND-HDA-00357__819ALS                                   0.0
#
#                                        ('16', '71924149', 'IST1')
# id                                                                 \
# ALS__CGND-HDA-01215__NEUUA360BR1                              0.0
# ALS__CGND-HDA-03062__UP-WGS-535                               1.0
# ALS__CGND-HDA-02741__PF-UCL-28                                0.0
# ALS__CGND-HDA-00353__358ALS                                   1.0
# ALS__CGND-HDA-01013__NEUFL908GEL                              1.0
# ALS__CGND-HDA-00872__MH-WASHU-250                             1.0
# ALS__CGND-HDA-01813__TD-ALS-136                               0.0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV
# aals-ALS__CGND-HDA-03444__NEUEB422WW0                           0.0
# aals-ALS__CGND-HDA-03886__NEUDP959KRY                           0.0
# ALS__CGND-HDA-00357__819ALS                                     0.0
#
# [695 rows x 54 columns]

# %% [markdown]
# ## Shapely value distribution for well-classified samples

# %%
def serialize_sample_shap(sampleValues):
    # some models only have probabilities for a single class
    return sampleValues.values[:,1] if len(sampleValues.values.shape) > 1 else sampleValues.values

serializedData = []
for sampleValues in accurateSamples['shapExplanations']:
    serializedData.append(serialize_sample_shap(sampleValues))
    
shapelyValueDataframe = pd.DataFrame(serializedData, columns=accurateSamples.iloc[0]['shapExplanations'].feature_names)
shapelyValueDataframe.index = accurateSamples['id']

# %%
accurateSamples['shapExplanations'].iloc[0].values[0]
# Out:
# array([ 0.00208532, -0.00208532])

# %%
shapelyValueDataframe
# Out:
#                                        1_186347356_TPR  1_225419442_LBR
# id                                                                       \
# ALS__CGND-HDA-00028__UP-WGS-211              -0.002085     1.105033e-05
# ALS__CGND-HDA-00028__UP-WGS-211               0.000000     0.000000e+00
# ALS__CGND-HDA-00028__UP-WGS-211              -0.031587     8.240942e-05
# ALS__CGND-HDA-00028__UP-WGS-211              -0.053750     0.000000e+00
# ALS__CGND-HDA-00028__UP-WGS-211              -0.003167     1.814708e-05
# ALS__CGND-HDA-00028__UP-WGS-211              -0.001699     0.000000e+00
# ALS__CGND-HDA-00028__UP-WGS-211               0.134497     0.000000e+00
# ALS__CGND-HDA-00028__UP-WGS-211              -0.020860     2.516267e-05
# ALS__CGND-HDA-00028__UP-WGS-211              -0.011680     7.367027e-05
# ALS__CGND-HDA-00028__UP-WGS-211              -0.025460    -6.109835e-06
# ALS__CGND-HDA-00028__UP-WGS-211              -0.014768     4.648942e-04
# ALS__CGND-HDA-00057__UP-WGS-241              -0.002339     5.526784e-05
# ALS__CGND-HDA-00057__UP-WGS-241               0.000000     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241              -0.002299     4.439709e-05
# ALS__CGND-HDA-00057__UP-WGS-241              -0.033488     2.469136e-04
# ALS__CGND-HDA-00057__UP-WGS-241               0.011042     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241              -0.000353     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241              -0.015618     1.897583e-03
# ALS__CGND-HDA-00057__UP-WGS-241              -0.001680     4.558489e-05
# ALS__CGND-HDA-00057__UP-WGS-241               0.000000     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241              -0.025000     9.239130e-04
# ALS__CGND-HDA-00057__UP-WGS-241              -0.004975     2.086158e-05
# ALS__CGND-HDA-00057__UP-WGS-241               0.000000     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241              -0.011453     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241              -0.024816     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241              -0.021114     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241               0.000766     1.000237e-03
# ALS__CGND-HDA-00057__UP-WGS-241              -0.031278     1.661017e-04
# ALS__CGND-HDA-00057__UP-WGS-241              -0.021906     5.445545e-04
# ALS__CGND-HDA-00057__UP-WGS-241              -0.038750     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241              -0.025000     0.000000e+00
# ALS__CGND-HDA-00057__UP-WGS-241              -0.163750     0.000000e+00
# ALS__CGND-HDA-00135__UP-WGS-320               0.004400     1.333333e-04
# ALS__CGND-HDA-00135__UP-WGS-320               0.000000     0.000000e+00
# ALS__CGND-HDA-00135__UP-WGS-320              -0.000208     0.000000e+00
# ALS__CGND-HDA-00135__UP-WGS-320              -0.033968     0.000000e+00
# ALS__CGND-HDA-00135__UP-WGS-320              -0.000833     3.703704e-04
# ...                                                ...              ...
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.000913     3.798463e-05
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.000000     0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.000000     1.250000e-03
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.000240     2.933198e-06
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        -0.000004     1.163469e-06
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.000173     2.868254e-05
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.012248     5.275229e-04
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.008363     4.287109e-05
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.000000     0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.000000     0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.000000     0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        -0.002488     1.230680e-05
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        -0.000002    -1.834201e-08
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        -0.000103     0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        -0.003390     1.279969e-04
# aals-ALS__CGND-HDA-04067__NEUJA207UUV         0.000000     0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        -0.000525     2.359699e-05
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0.001617     9.666667e-04
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0.005000     0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        -0.002843    -8.384146e-05
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0.000521     2.548655e-05
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0.002500     0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0.002500     0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0.010000     0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0.001400    -2.678222e-05
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0.004582    -3.811273e-05
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0.002255     8.050876e-05
# aals-ALS__CGND-HDA-04071__NEUCD063FGD         0
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        5.711642e-03
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV       -5.000000e-03
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        6.832266e-03
# aals-ALS__CGND-HDA-04067__NEUJA207UUV       -6.523936e-06
# aals-ALS__CGND-HDA-04067__NEUJA207UUV       -4.643553e-05
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        2.293578e-04
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        5.740689e-04
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV       -1.546812e-03
# aals-ALS__CGND-HDA-04067__NEUJA207UUV       -3.352667e-07
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        4.399490e-04
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        1.570305e-04
# aals-ALS__CGND-HDA-04067__NEUJA207UUV        0.000000e+00
# aals-ALS__CGND-HDA-04067__NEUJA207UUV       -2.204778e-03
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        3.800000e-03
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        1.379573e-03
# aals-ALS__CGND-HDA-04071__NEUCD063FGD       -1.107141e-03
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        2.500000e-03
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        2.000000e-02
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        5.437653e-04
# aals-ALS__CGND-HDA-04071__NEUCD063FGD       -4.311108e-03
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        3.589974e-04
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        4.818332e-03
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        1.506045e-05
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        1.105372e-03
# aals-ALS__CGND-HDA-04071__NEUCD063FGD       -6.464013e-05
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        0.000000e+00
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        2.064820e-04
# aals-ALS__CGND-HDA-04071__NEUCD063FGD        3.454197e-03
#
# [4580 rows x 54 columns]

# %%
import numpy as np
import plotly.express as px

df_stats = shapelyValueDataframe.describe().T

# Create a DataFrame for the plotting
df_plot_mean = df_stats[['mean']].reset_index()
df_plot_std = df_stats[['std']].reset_index()

# Sort by the greatest mean Shapley value and least standard deviation
df_plot_mean = df_plot_mean.sort_values(['mean'], ascending=False)
df_plot_std = df_plot_std.sort_values(['std'], ascending=True)

# Create a bar chart for means
fig_mean = px.bar(df_plot_mean, x='index', y='mean', labels={'index':'Feature', 'mean':'Mean Shapely Value'})
fig_mean.show()

# Create a bar chart for standard deviations
fig_std = px.bar(df_plot_std, x='index', y='std', labels={'index':'Feature', 'std':'Standard Deviation'})
fig_std.show()

# %%
df_stats[['mean', 'std']].corr(method='pearson')
# Out:
#           mean       std
# mean  1.000000  0.714121
# std   0.714121  1.000000

# %%
accurateCases = [id for id in accurateSamples['id'].unique() if "CTR" not in id]
pd.Series(accurateCases, name='id').to_csv('accurateCases.csv', index=False)

# %%
discordantSampleIDs = discordantSamples['id'].unique()
discordantCases = [id for id in discordantSampleIDs if "CTR" not in id]
pd.Series(discordantCases, name='id').to_csv('discordantCases.csv', index=False)

# %%
discordantSampleIDs
# Out:
# array(['ALS__CGND-HDA-00277__2140ALS', 'ALS__CGND-HDA-00317__362ALS',
#        'ALS__CGND-HDA-00323__820ALS', 'ALS__CGND-HDA-00332__2271ALS',
#        'ALS__CGND-HDA-00360__125ALS', 'ALS__CGND-HDA-00782__MH-WASHU-160',
#        'ALS__CGND-HDA-00845__MH-WASHU-223',
#        'ALS__CGND-HDA-01098__276-11-5',
#        'ALS__CGND-HDA-01224__NEUUM419GYB', 'ALS__CGND-HDA-01294__EC11',
#        'ALS__CGND-HDA-01489__NEUGY188ZTM',
#        'ALS__CGND-HDA-01539__UP-WGS-017',
#        'ALS__CGND-HDA-01591__UP-WGS-069',
#        'ALS__CGND-HDA-01795__TD-ALS-87',
#        'ALS__CGND-HDA-01824__TD-ALS-129',
#        'ALS__CGND-HDA-01897__TD-ALS-143',
